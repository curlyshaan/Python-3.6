# %%
import bs4
import csv
import requests 

res= requests.get('http://curlyshaan.com/belgium-chocolates-in-chennai/')
ret= requests.get('http://curlyshaan.com/')

csvfile=open('cs_links.csv','w')

csv_writer=csv.writer(csvfile)
csv_writer.writerow(['Links'])
# Out:
# 7

# %%
type(res)
type(ret)
# Out:
# requests.models.Response

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '<!DOCTYPE html>\r\n<html lang="en-US" prefix="og: http://ogp.me/ns#">\r\n\r\n<head>\r\n<meta charset="UTF-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<link rel="profile" href="http://gmpg.org/xfn/11">\r\n<link rel="pingback" href="http://curlyshaan.com/xmlrpc.php">\r\n\r\n<title>Belgium Chocolates In Chennai - Curly Shaan</title>\n\n<!-- This site is optimized with the Yoast SEO plugin v4.9 - https://yoast.com/wordpress/plugins/seo/ -->\n<link rel="canonical" href="http://curlyshaan.com/belgium-chocolates-in-chennai/" />\n<meta property="og:locale" content="en_US" />\n<meta property="og:type" content="article" />\n<meta property="og:title" content="Belgium Chocolates In Chennai - Curly Shaan" />\n<meta property="og:description" content="It didn’t have the best of starts, my parents suddenly grew uncomfortable with Couch Surfing, and I couldn’t offer space" />\n<meta property="og:url" content="http://curlyshaan.com/belgium-chocolates-in-chennai/" />
# ...

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')
salt = bs4.BeautifulSoup(ret.text,'lxml')

# %%
type(soup)
type(salt)
# Out:
# bs4.BeautifulSoup

# %%
article=soup.find('article')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://curlyshaan.com/xmlrpc.php" rel="pingback"/>
#   <title>
#    Belgium Chocolates In Chennai - Curly Shaan
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v4.9 - https://yoast.com/wordpress/plugins/seo/ -->
#   <link href="http://curlyshaan.com/belgium-chocolates-in-chennai/" rel="canonical"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Belgium Chocolates In Chennai - Curly Shaan" property="og:title"/>
#   <meta content="It didn’t have the best of starts, my parents suddenly grew uncomfortable with Couch Surfing, and I couldn’t offer space" property="og:description"/>
# ...

# %%
for im in soup.find_all('div', class_='site-content container clearfix'):
    print(im.text)
# Out:
# Belgium Chocolates In Chennai
# September 13, 2016 Sai Shanoor Short Bytes, Travelogue Leave a comment
#
#
# It didn’t have the best of starts, my parents suddenly grew uncomfortable with Couch Surfing, and I couldn’t offer space to Amelie and Adrien. I personally love the idea, for the traveler in me it is intruding, an established platform to connect and converse with local people and get a firsthand experience of life in a new city. I can imagine how things aren’t as expected for people traveling to India for the first time, for example, if I am not wrong both Amelie and Adrien all had was a thousand rupees (Indian currency) which was so not adequate. Seems like both got wrong with the structure of pricing in Indian economy. I suggested them to take a taxi or local train to reach my place, I was cheering for the latter option hoping that they would get to experience a real side of Chennai than a pretty-fake ‘straight to the taxi from flight’ as shown in the movies.
# ...

# %%
print(article.text)
# Out:
# Belgium Chocolates In Chennai
# September 13, 2016 Sai Shanoor Short Bytes, Travelogue Leave a comment
#
#
# It didn’t have the best of starts, my parents suddenly grew uncomfortable with Couch Surfing, and I couldn’t offer space to Amelie and Adrien. I personally love the idea, for the traveler in me it is intruding, an established platform to connect and converse with local people and get a firsthand experience of life in a new city. I can imagine how things aren’t as expected for people traveling to India for the first time, for example, if I am not wrong both Amelie and Adrien all had was a thousand rupees (Indian currency) which was so not adequate. Seems like both got wrong with the structure of pricing in Indian economy. I suggested them to take a taxi or local train to reach my place, I was cheering for the latter option hoping that they would get to experience a real side of Chennai than a pretty-fake ‘straight to the taxi from flight’ as shown in the movies.
# ...

# %%
for ih in soup.find('div', class_='entry-content clearfix'):
    print(ih)
# Out:
# <p>It didn’t have the best of starts, my parents suddenly grew uncomfortable with <a href="http://couchsurfing.com">Couch Surfing</a>, and I couldn’t offer space to Amelie and Adrien. I personally love the idea, for the traveler in me it is intruding, an established platform to connect and converse with local people and get a firsthand experience of life in a new city. I can imagine how things aren’t as expected for people traveling to India for the first time, for example, if I am not wrong both Amelie and Adrien all had was a thousand rupees (Indian currency) which was so not adequate. Seems like both got wrong with the structure of pricing in Indian economy. I suggested them to take a taxi or local train to reach my place, I was cheering for the latter option hoping that they would get to experience a real side of Chennai than a pretty-fake ‘straight to the taxi from flight’ as shown in the movies.</p>
#
#
# ...

# %%
for art in salt.find_all('a'):
    print(art.prettify())
# Out:
# <a class="skip-link screen-reader-text" href="#content">
#  Skip to content
# </a>
#
# <a href="http://curlyshaan.com/" rel="home">
#  Curly Shaan
# </a>
# <a href="http://curlyshaan.com/">
#  Home
# </a>
# <a href="http://curlyshaan.com/category/articles/">
#  Articles
# </a>
# <a href="http://curlyshaan.com/category/short-bytes/">
#  Short Bytes
# </a>
# <a href="http://curlyshaan.com/category/travelogue/">
#  Travelogue
# </a>
# <a href="http://curlyshaan.com/category/short-stories/">
#  Short Stories
# </a>
# <a href="http://curlyshaan.com/hire-me/">
#  HIRE ME!
# </a>
# <a href="http://curlyshaan.com/call-trip-south-america/" rel="bookmark">
#  Call for Trip to South America
# </a>
# <a href="http://curlyshaan.com/call-trip-south-america/" rel="bookmark" title="1:53 am">
#  <time class="entry-date published updated" datetime="2017-05-16T01:53:41+00:00">
#   May 16, 2017
#  </time>
# </a>
# ...

# %%
print(salt.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="http://gmpg.org/xfn/11" rel="profile"/>
#   <link href="http://curlyshaan.com/xmlrpc.php" rel="pingback"/>
#   <title>
#    Curly Shaan - Blog
#   </title>
#   <!-- This site is optimized with the Yoast SEO plugin v4.9 - https://yoast.com/wordpress/plugins/seo/ -->
#   <meta content="Blog" name="description"/>
#   <link href="http://curlyshaan.com/" rel="canonical"/>
#   <link href="http://curlyshaan.com/page/2/" rel="next"/>
#   <meta content="en_US" property="og:locale"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Curly Shaan - Blog" property="og:title"/>
#   <meta content="Blog" property="og:description"/>
#   <meta content="http://curlyshaan.com/" property="og:url"/>
#   <meta content="Curly Shaan" property="og:site_name"/>
# ...

# %%
for link in soup.findAll('a', href=True):
        print(link['href'])
# Out:
# #content
# http://curlyshaan.com/
# http://curlyshaan.com/
# http://curlyshaan.com/category/articles/
# http://curlyshaan.com/category/short-bytes/
# http://curlyshaan.com/category/travelogue/
# http://curlyshaan.com/category/short-stories/
# http://curlyshaan.com/hire-me/
# http://curlyshaan.com/belgium-chocolates-in-chennai/
# http://curlyshaan.com/author/Sai%20Shanoor/
# http://curlyshaan.com/category/short-bytes/
# http://curlyshaan.com/category/travelogue/
# http://curlyshaan.com/belgium-chocolates-in-chennai/#respond
# http://couchsurfing.com
# http://curlyshaan.com/tag/beach/
# http://curlyshaan.com/tag/beers/
# http://curlyshaan.com/tag/belgium/
# http://curlyshaan.com/tag/chennai/
# http://curlyshaan.com/tag/chocoloates/
# http://curlyshaan.com/tag/europe/
# http://curlyshaan.com/tag/foreign/
# http://curlyshaan.com/tag/foreigners/
# http://curlyshaan.com/tag/french/
# http://curlyshaan.com/tag/hampi/
# http://curlyshaan.com/tag/india/
# http://curlyshaan.com/tag/karnataka/
# ...

# %%
for art in soup.findAll('a'):
    print (art['href'])
# Out:
# #content
# http://curlyshaan.com/
# http://curlyshaan.com/
# http://curlyshaan.com/category/articles/
# http://curlyshaan.com/category/short-bytes/
# http://curlyshaan.com/category/travelogue/
# http://curlyshaan.com/category/short-stories/
# http://curlyshaan.com/hire-me/
# http://curlyshaan.com/belgium-chocolates-in-chennai/
# http://curlyshaan.com/author/Sai%20Shanoor/
# http://curlyshaan.com/category/short-bytes/
# http://curlyshaan.com/category/travelogue/
# http://curlyshaan.com/belgium-chocolates-in-chennai/#respond
# http://couchsurfing.com
# http://curlyshaan.com/tag/beach/
# http://curlyshaan.com/tag/beers/
# http://curlyshaan.com/tag/belgium/
# http://curlyshaan.com/tag/chennai/
# http://curlyshaan.com/tag/chocoloates/
# http://curlyshaan.com/tag/europe/
# http://curlyshaan.com/tag/foreign/
# http://curlyshaan.com/tag/foreigners/
# http://curlyshaan.com/tag/french/
# http://curlyshaan.com/tag/hampi/
# http://curlyshaan.com/tag/india/
# http://curlyshaan.com/tag/karnataka/
# ...

# %%
csvfile.close()

# %%
from more_itertools import unique_everseen
with open('cs_links.csv','r') as f, open('2.csv','w') as out_file:
    out_file.writelines(unique_everseen(f))
